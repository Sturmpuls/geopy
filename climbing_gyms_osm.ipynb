# %%
import main
import pandas as pd
import geopandas
import folium

# %%
file = r"data\climbing_facilities\climbing_facilities_2019-11-10.geojson"
geo = geopandas.read_file(file)

# %%
m = folium.Map([48.0, 7.7], zoom_start=8, tiles='cartodbpositron')
folium.GeoJson(geo).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([48.0, 7.7], zoom_start=8, tiles='cartodbpositron')

html="""
    <h4>DAV Kletterzentrum</h4>
    <b>Tags</b><br>
    <div>
        leisure=sports_centre<br>
        sport=climbing<br>
        tag=popup<br>
        website=<a href=http://www.example.de>http://www.example.de<br>
    </div>
"""
popup = folium.Popup(html, max_width=300)
folium.Marker([48.0, 8.2], popup=popup, icon=folium.Icon(color='red', icon='info-sign')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
